# %%
import pandas as pd

# %%
df = pd.DataFrame({"id":[1,2,3,4,5],
                   "name":["A","B","C","D","E"],
                   "DOJ":['01-05-2023','05-08-2022','06-02-2021','05-11-2025','04-03-2025']})

# %%
df
# Out:
#    id name         DOJ
# 0   1    A  01-05-2023
# 1   2    B  05-08-2022
# 2   3    C  06-02-2021
# 3   4    D  05-11-2025
# 4   5    E  04-03-2025

# %%
df.dtypes
# Out:
# id       int64
# name    object
# DOJ     object
# dtype: object

# %%
df['DOJ_date'] = pd.to_datetime(df['DOJ'])

# %%
df
# Out:
#    id name         DOJ   DOJ_date
# 0   1    A  01-05-2023 2023-01-05
# 1   2    B  05-08-2022 2022-05-08
# 2   3    C  06-02-2021 2021-06-02
# 3   4    D  05-11-2025 2025-05-11
# 4   5    E  04-03-2025 2025-04-03

# %%
df.dtypes
# Out:
# id                   int64
# name                object
# DOJ                 object
# DOJ_date    datetime64[ns]
# dtype: object

# %%
df['month' ] =df['DOJ_date'].dt.month

# %%
df
# Out:
#    id name         DOJ   DOJ_date  month
# 0   1    A  01-05-2023 2023-01-05      1
# 1   2    B  05-08-2022 2022-05-08      5
# 2   3    C  06-02-2021 2021-06-02      6
# 3   4    D  05-11-2025 2025-05-11      5
# 4   5    E  04-03-2025 2025-04-03      4

# %%
  df['year']= df['DOJ_date'].dt.year

# %%
df['day']= df['DOJ_date'].dt.day

# %%
df
# Out:
#    id name         DOJ   DOJ_date  month  year  day
# 0   1    A  01-05-2023 2023-01-05      1  2023    5
# 1   2    B  05-08-2022 2022-05-08      5  2022    8
# 2   3    C  06-02-2021 2021-06-02      6  2021    2
# 3   4    D  05-11-2025 2025-05-11      5  2025   11
# 4   5    E  04-03-2025 2025-04-03      4  2025    3

# %%
df = pd.DataFrame({"id":[1,2,3,4,5],
                   "name":["A","B","C","D","E"],
                   "DOJ":['01st/May/2023','02nd/Jun/2023','04th/Dec/2023','07th/Mar/2023','02nd/Feb/2023']})

# %%
df['DOJ'].map({"st":'',"rd":'',"th":'',"nd":''})
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: DOJ, dtype: object

# %%
df['DOJ'] = df['DOJ'].str.replace('st','')

# %%
df['DOJ'] = df['DOJ'].str.replace('th','')

# %%
df
# Out:
#    id name          DOJ
# 0   1    A  01/May/2023
# 1   2    B  02/Jun/2023
# 2   3    C  04/Dec/2023
# 3   4    D  07/Mar/2023
# 4   5    E  02/Feb/2023

# %%
01/May/2023   --- '01-05-2023'

# %%
import calendar

# %%
df['DOJ_date'] =df['DOJ'].map(lambda x: x.split('/')[0]+"-"+str(datetime.strptime(x.split('/')[1], "%b").month)+"-"+x.split('/')[2])

# %%
df
# Out:
#    id name          DOJ    DOJ_date
# 0   1    A  01/May/2023   01-5-2023
# 1   2    B  02/Jun/2023   02-6-2023
# 2   3    C  04/Dec/2023  04-12-2023
# 3   4    D  07/Mar/2023   07-3-2023
# 4   5    E  02/Feb/2023   02-2-2023

# %%
df['test'] = pd.to_datetime(df['DOJ_date'],format='%d-%m-%Y')

# %%
df
# Out:
#    id name          DOJ    DOJ_date       test
# 0   1    A  01/May/2023   01-5-2023 2023-05-01
# 1   2    B  02/Jun/2023   02-6-2023 2023-06-02
# 2   3    C  04/Dec/2023  04-12-2023 2023-12-04
# 3   4    D  07/Mar/2023   07-3-2023 2023-03-07
# 4   5    E  02/Feb/2023   02-2-2023 2023-02-02

# %%
df = pd.read_csv("temp.csv")

# %%
df
# Out:
#     order_id customer region   product  quantity  price   sale_date
# 0          1    Alice  North    Laptop         1   1200  2024-01-05
# 1          2      Bob  South  Keyboard         3     40  2024-01-07
# 2          3  Charlie   East     Mouse         5     10  2024-01-08
# 3          4    Alice  North   Monitor         2    200  2024-01-10
# 4          5    David   West    Laptop         1   1300  2024-01-12
# 5          6      Eva  South     Mouse        10      8  2024-01-12
# 6          7    Frank  North     Mouse         2     12  2024-01-15
# 7          8    Alice   East  Keyboard         1     45  2024-01-16
# 8          9      Bob  South   Monitor         1    210  2024-01-17
# 9         10      Eva   West    Laptop         1   1400  2024-01-20
# 10        11  Charlie   East    Laptop         2   1250  2024-01-21
# 11        12    Frank  North  Keyboard         4     42  2024-01-22
# 12        13    Alice  South     Mouse         6      9  2024-01-23
# ...

# %%
final = df.groupby(['product','region']).agg('price').sum()

# %%
pd.DataFrame(final).reset_index().groupby("
# Out:
#      product region  price
# 0   Keyboard   East     83
# 1   Keyboard  North     42
# 2   Keyboard  South     40
# 3     Laptop   East   1250
# 4     Laptop  North   1200
# 5     Laptop   West   2700
# 6    Monitor  North    200
# 7    Monitor  South    210
# 8    Monitor   West    220
# 9      Mouse   East     10
# 10     Mouse  North     12
# 11     Mouse  South     17
